# %% [markdown]
# <a href="https://colab.research.google.com/github/Kits1700/WaterEnergy/blob/main/AirRandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %%
# resample minute data to total for each day
from pandas import read_csv
# load the new file
dataset = read_csv('/content/drive/My Drive/city_day.csv', header=0, index_col=0)
dataset.head(20)
# Out:
#                  Date  PM2.5  PM10      NO  ...  Toluene  Xylene  AQI  AQI_Bucket
# City                                        ...
# Ahmedabad  2015-01-01    NaN   NaN    0.92  ...     0.02    0.00  NaN         NaN
# Ahmedabad  2015-01-02    NaN   NaN    0.97  ...     5.50    3.77  NaN         NaN
# Ahmedabad  2015-01-03    NaN   NaN   17.40  ...    16.40    2.25  NaN         NaN
# Ahmedabad  2015-01-04    NaN   NaN    1.70  ...    10.14    1.00  NaN         NaN
# Ahmedabad  2015-01-05    NaN   NaN   22.10  ...    18.89    2.78  NaN         NaN
# Ahmedabad  2015-01-06    NaN   NaN   45.41  ...    10.83    1.93  NaN         NaN
# Ahmedabad  2015-01-07    NaN   NaN  112.16  ...     0.00    0.00  NaN         NaN
# Ahmedabad  2015-01-08    NaN   NaN   80.87  ...     0.00    0.00  NaN         NaN
# Ahmedabad  2015-01-09    NaN   NaN   29.16  ...     0.00    0.00  NaN         NaN
# Ahmedabad  2015-01-10    NaN   NaN     NaN  ...     0.00    0.00  NaN         NaN
# ...

# %%
# mark all missing values
from numpy import nan
dataset.replace('?', nan, inplace=True)
# make dataset numeric
dataset = dataset.astype('float32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b59bfe2eb071> in <module>()
#       3 dataset.replace('?', nan, inplace=True)
#       4 # make dataset numeric
# ----> 5 dataset = dataset.astype('float32')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# ...

# %%
dataset.dtypes
# Out:
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
import pandas as pd
dataset.Date = pd.to_datetime(dataset.Date)

# %%
dataset.dtypes
# Out:
# Date          datetime64[ns]
# PM2.5                float64
# PM10                 float64
# NO                   float64
# NO2                  float64
# NOx                  float64
# NH3                  float64
# CO                   float64
# SO2                  float64
# O3                   float64
# Benzene              float64
# Toluene              float64
# Xylene               float64
# AQI                  float64
# AQI_Bucket            object
# dtype: object

# %%
# fill missing values with a value at the same time one day ago
from numpy import isnan
def fill_missing(x):
    	if isnan(x):
				  x=0.0

# %%
# fill missing
fill_missing(dataset.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-0d0249a7555c> in <module>()
#       1 # fill missing
# ----> 2 fill_missing(dataset.values)
#
# <ipython-input-28-0cd883a4c190> in fill_missing(x)
#       2 from numpy import isnan
#       3 def fill_missing(x):
# ----> 4         if isnan(x):
#       5                                   x=0.0
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
X = dataset['Date'].values
y = dataset['NO2'].values

# %%
print(y)
# Out:
# [18.22 15.69 19.3  ... 29.53 29.26 26.85]

# %%
print(X)
# Out:
# ['2015-01-01T00:00:00.000000000' '2015-01-02T00:00:00.000000000'
#  '2015-01-03T00:00:00.000000000' ... '2020-06-29T00:00:00.000000000'
#  '2020-06-30T00:00:00.000000000' '2020-07-01T00:00:00.000000000']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05)

# %%
# Fitting Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train.reshape(-1,1), y_train.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-cade36db796f> in <module>()
#       2 from sklearn.ensemble import RandomForestRegressor
#       3 regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
# ----> 4 regressor.fit(X_train.reshape(-1,1), y_train.reshape(-1,1))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     294         # Validate or convert input data
#     295         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
# --> 296         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     297         if sample_weight is not None:
#     298             sample_weight = _check_sample_weight(sample_weight, X)
#
# ...

# %%
print(dataset)
remove_nan = dataset. dropna()
print(remove_nan)
# Out:
#                     Date  PM2.5   PM10  ...  Xylene   AQI    AQI_Bucket
# City                                    ...
# Ahmedabad     2015-01-01    NaN    NaN  ...    0.00   NaN           NaN
# Ahmedabad     2015-01-02    NaN    NaN  ...    3.77   NaN           NaN
# Ahmedabad     2015-01-03    NaN    NaN  ...    2.25   NaN           NaN
# Ahmedabad     2015-01-04    NaN    NaN  ...    1.00   NaN           NaN
# Ahmedabad     2015-01-05    NaN    NaN  ...    2.78   NaN           NaN
# ...                  ...    ...    ...  ...     ...   ...           ...
# Visakhapatnam 2020-06-27  15.02  50.94  ...    0.73  41.0          Good
# Visakhapatnam 2020-06-28  24.38  74.09  ...    0.38  70.0  Satisfactory
# Visakhapatnam 2020-06-29  22.91  65.73  ...    0.00  68.0  Satisfactory
# Visakhapatnam 2020-06-30  16.64  49.97  ...    0.00  54.0  Satisfactory
# Visakhapatnam 2020-07-01  15.00  66.00  ...     NaN  50.0          Good
#
# [29531 rows x 15 columns]
# ...

# %%
dataset.head()
# Out:
#                 Date  PM2.5  PM10     NO  ...  Toluene  Xylene  AQI  AQI_Bucket
# City                                      ...
# Ahmedabad 2015-01-01    NaN   NaN   0.92  ...     0.02    0.00  NaN         NaN
# Ahmedabad 2015-01-02    NaN   NaN   0.97  ...     5.50    3.77  NaN         NaN
# Ahmedabad 2015-01-03    NaN   NaN  17.40  ...    16.40    2.25  NaN         NaN
# Ahmedabad 2015-01-04    NaN   NaN   1.70  ...    10.14    1.00  NaN         NaN
# Ahmedabad 2015-01-05    NaN   NaN  22.10  ...    18.89    2.78  NaN         NaN
#
# [5 rows x 15 columns]

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#                     Date  PM2.5   PM10  ...  Xylene   AQI    AQI_Bucket
# City                                    ...
# Ahmedabad     2015-01-01    NaN    NaN  ...    0.00   NaN           NaN
# Ahmedabad     2015-01-02    NaN    NaN  ...    3.77   NaN           NaN
# Ahmedabad     2015-01-03    NaN    NaN  ...    2.25   NaN           NaN
# Ahmedabad     2015-01-04    NaN    NaN  ...    1.00   NaN           NaN
# Ahmedabad     2015-01-05    NaN    NaN  ...    2.78   NaN           NaN
# ...                  ...    ...    ...  ...     ...   ...           ...
# Visakhapatnam 2020-06-27  15.02  50.94  ...    0.73  41.0          Good
# Visakhapatnam 2020-06-28  24.38  74.09  ...    0.38  70.0  Satisfactory
# Visakhapatnam 2020-06-29  22.91  65.73  ...    0.00  68.0  Satisfactory
# Visakhapatnam 2020-06-30  16.64  49.97  ...    0.00  54.0  Satisfactory
# Visakhapatnam 2020-07-01  15.00  66.00  ...     NaN  50.0          Good
#
# [29531 rows x 15 columns]

# %%
df=df.dropna()

# %%
df
# Out:
#                     Date  PM2.5    PM10  ...  Xylene    AQI    AQI_Bucket
# City                                     ...
# Amaravati     2017-11-25  81.40  124.50  ...    0.06  184.0      Moderate
# Amaravati     2017-11-26  78.32  129.06  ...    0.08  197.0      Moderate
# Amaravati     2017-11-27  88.76  135.32  ...    0.12  198.0      Moderate
# Amaravati     2017-11-28  64.18  104.09  ...    0.07  188.0      Moderate
# Amaravati     2017-11-29  72.47  114.84  ...    0.08  173.0      Moderate
# ...                  ...    ...     ...  ...     ...    ...           ...
# Visakhapatnam 2020-06-26   7.63   32.27  ...    1.45   47.0          Good
# Visakhapatnam 2020-06-27  15.02   50.94  ...    0.73   41.0          Good
# Visakhapatnam 2020-06-28  24.38   74.09  ...    0.38   70.0  Satisfactory
# Visakhapatnam 2020-06-29  22.91   65.73  ...    0.00   68.0  Satisfactory
# Visakhapatnam 2020-06-30  16.64   49.97  ...    0.00   54.0  Satisfactory
#
# [6236 rows x 15 columns]

# %%
dataset.values=df.values
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5169                 else:
# -> 5170                     object.__setattr__(self, name, value)
#    5171             except (AttributeError, TypeError):
#
# AttributeError: can't set attribute
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-408b4b8be5fa> in <module>()
# ----> 1 dataset.values=df.values
#
# ...

# %%
dataset.head()
# Out:
#                 Date  PM2.5  PM10     NO  ...  Toluene  Xylene  AQI  AQI_Bucket
# City                                      ...
# Ahmedabad 2015-01-01    NaN   NaN   0.92  ...     0.02    0.00  NaN         NaN
# Ahmedabad 2015-01-02    NaN   NaN   0.97  ...     5.50    3.77  NaN         NaN
# Ahmedabad 2015-01-03    NaN   NaN  17.40  ...    16.40    2.25  NaN         NaN
# Ahmedabad 2015-01-04    NaN   NaN   1.70  ...    10.14    1.00  NaN         NaN
# Ahmedabad 2015-01-05    NaN   NaN  22.10  ...    18.89    2.78  NaN         NaN
#
# [5 rows x 15 columns]

# %%
df.head()
# Out:
#                 Date  PM2.5    PM10    NO  ...  Toluene  Xylene    AQI  AQI_Bucket
# City                                       ...
# Amaravati 2017-11-25  81.40  124.50  1.44  ...     6.50    0.06  184.0    Moderate
# Amaravati 2017-11-26  78.32  129.06  1.26  ...     7.95    0.08  197.0    Moderate
# Amaravati 2017-11-27  88.76  135.32  6.60  ...     7.63    0.12  198.0    Moderate
# Amaravati 2017-11-28  64.18  104.09  2.56  ...     5.02    0.07  188.0    Moderate
# Amaravati 2017-11-29  72.47  114.84  5.23  ...     4.71    0.08  173.0    Moderate
#
# [5 rows x 15 columns]

# %%
X = df['Date'].values
y = df['NO2'].values

# %%
print(X)
# Out:
# ['2017-11-25T00:00:00.000000000' '2017-11-26T00:00:00.000000000'
#  '2017-11-27T00:00:00.000000000' ... '2020-06-28T00:00:00.000000000'
#  '2020-06-29T00:00:00.000000000' '2020-06-30T00:00:00.000000000']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05)

# %%
# Fitting Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train.reshape(-1,1), y_train.reshape(-1,1))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
y_pred = regressor.predict(X_test.reshape(-1,1))

# %%
import pandas as pd
df = pd.DataFrame({'Real Values':y_test.reshape(-1), 'Predicted Values':y_pred.reshape(-1)})
df
# Out:
#      Real Values  Predicted Values
# 0           9.80         21.876935
# 1          29.22         28.457550
# 2          25.11         18.566286
# 3         124.57         69.451333
# 4          48.37         26.020679
# ..           ...               ...
# 307        46.37         34.976183
# 308        48.78         59.904550
# 309        12.66         26.454517
# 310        11.75         50.627000
# 311        23.75         26.549600
#
# [312 rows x 2 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.scatter(X_test, y_test, color = 'red')
plt.scatter(X_test, y_pred, color = 'green')
plt.title('Random Forest Regression')
plt.xlabel('Year')
plt.ylabel('Air Quality')
plt.show()

# %%
plt.plot(X_test, y_pred, color = 'green')
plt.title('Random Forest Regression')
plt.xlabel('Year')
plt.ylabel('Water Consumed')
plt.show()
